# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Ratnadeep/Desktop/python/Self Based Pandas/data.csv')
df
# Out:
#                                                Url Car  \
# 0    https://ikman.lk/en/ad/audi-a4-20tdi-2014-for-...
# 1    https://ikman.lk/en/ad/mercedes-benz-e300-nigh...
# 2    https://ikman.lk/en/ad/mercedes-benz-c200-head...
# 3    https://ikman.lk/en/ad/toyota-axio-x-grade-200...
# 4    https://ikman.lk/en/ad/micro-panda-12000kms-20...
# ..                                                 ...
# 263  https://ikman.lk/en/ad/alfa-romeo-fiat-uno-lks...
# 264  https://ikman.lk/en/ad/toyota-land-cruiser-pra...
# 265  https://ikman.lk/en/ad/mercedes-benz-c180-cabr...
# 266  https://ikman.lk/en/ad/bmw-x1-s-drive-diesel-2...
# 267  https://ikman.lk/en/ad/toyota-prius-s-grade-20...
#
#                                        Name     Price          Brand  \
# 0                       Audi A4 2.0TDi 2014   72500.0           Audi
# 1     Mercedes Benz E300 Night Edition 2015  107500.0  Mercedes Benz
# 2    Mercedes Benz C200 headup display 2015  109000.0  Mercedes Benz
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#show 1st 5 record
df.head()
# Out:
#                                              Url Car  \
# 0  https://ikman.lk/en/ad/audi-a4-20tdi-2014-for-...
# 1  https://ikman.lk/en/ad/mercedes-benz-e300-nigh...
# 2  https://ikman.lk/en/ad/mercedes-benz-c200-head...
# 3  https://ikman.lk/en/ad/toyota-axio-x-grade-200...
# 4  https://ikman.lk/en/ad/micro-panda-12000kms-20...
#
#                                      Name     Price          Brand Condition  \
# 0                     Audi A4 2.0TDi 2014   72500.0           Audi      Used
# 1   Mercedes Benz E300 Night Edition 2015  107500.0  Mercedes Benz      Used
# 2  Mercedes Benz C200 headup display 2015  109000.0  Mercedes Benz      Used
# 3                Toyota Axio X Grade 2007   31125.0         Toyota      Used
# 4               Micro Panda 12000KMs 2015   12475.0          Micro      Used
#
#          Img                                            Img Url
# 0  Img/0.png  https://i.ikman-st.com/audi-a4-20tdi-2014-for-...
# ...

# %%
df.tail()
# Out:
#                                                Url Car  \
# 263  https://ikman.lk/en/ad/alfa-romeo-fiat-uno-lks...
# 264  https://ikman.lk/en/ad/toyota-land-cruiser-pra...
# 265  https://ikman.lk/en/ad/mercedes-benz-c180-cabr...
# 266  https://ikman.lk/en/ad/bmw-x1-s-drive-diesel-2...
# 267  https://ikman.lk/en/ad/toyota-prius-s-grade-20...
#
#                                   Name     Price          Brand Condition  \
# 263                      Fiat Uno 1984    2750.0           Fiat      Used
# 264     Toyota Land Cruiser Prado 2003   59375.0         Toyota      Used
# 265  Mercedes Benz C180 Cabriolet 2017  140000.0  Mercedes Benz      Used
# 266         BMW X1 S Drive Diesel 2011   57250.0            BMW      Used
# 267          Toyota Prius S Grade 2015   42750.0         Toyota      Used
#
#            Img                                            Img Url
# 263  Img/0.png  https://i.ikman-st.com/alfa-romeo-fiat-uno-lks...
# ...

# %%
#show last two row
df.tail(2)
# Out:
#                                                Url Car  \
# 266  https://ikman.lk/en/ad/bmw-x1-s-drive-diesel-2...
# 267  https://ikman.lk/en/ad/toyota-prius-s-grade-20...
#
#                            Name    Price   Brand Condition        Img  \
# 266  BMW X1 S Drive Diesel 2011  57250.0     BMW      Used  Img/0.png
# 267   Toyota Prius S Grade 2015  42750.0  Toyota      Used  Img/0.png
#
#                                                Img Url
# 266  https://i.ikman-st.com/bmw-x1-s-drive-diesel-2...
# 267  https://i.ikman-st.com/toyota-prius-s-grade-20...

# %%
#tab separated
df2 = pd.read_table('C:/Users/Ratnadeep/Desktop/python/Self Based Pandas/Tabseparated _data.txt',sep='\t')
df2
# Out:
#    id   name   sal
# 0   1   deep  2000
# 1   2  ratna  3000
# 2   3   puja   120

# %%
df3 = pd.read_table('C:/Users/Ratnadeep/Desktop/python/Self Based Pandas/Tabseparated _data.txt', header=2)
df3
# Out:
#    2 ratna  3000
# 0  3  puja   120

# %%
df4 = pd.read_table('C:/Users/Ratnadeep/Desktop/python/Self Based Pandas/Tabseparated _data.txt', header=None)
df4
# Out:
#     0      1     2
# 0  id   name   sal
# 1   1   deep  2000
# 2   2  ratna  3000
# 3   3   puja   120

# %%
#givin my owm column name
#if extra name is given then will
df5 = pd.read_table('C:/Users/Ratnadeep/Desktop/python/Self Based Pandas/Tabseparated _data.txt',names=["Emp_id","Employee_Name","Salary","new"])
df5
# Out:
#   Emp_id Employee_Name Salary  new
# 0     id          name    sal  NaN
# 1      1          deep   2000  NaN
# 2      2         ratna   3000  NaN
# 3      3          puja    120  NaN

# %%
#index change
indxDF2 = pd.read_table('C:/Users/Ratnadeep/Desktop/python/Self Based Pandas/index.txt',index_col=['id'])
indxDF2
# Out:
#      name   sal
# id
# 1    deep  2000
# 1   ratna  3000
# 1    puja   120
# 2    deep   200
# 2   ratna  3565
# 2    puja  9987

# %%
#index under index
indxDF2 = pd.read_table('C:/Users/Ratnadeep/Desktop/python/Self Based Pandas/index.txt',index_col=['id','name'])
indxDF2
# Out:
#            sal
# id name
# 1  deep   2000
#    ratna  3000
#    puja    120
# 2  deep    200
#    ratna  3565
#    puja   9987

# %%
#skip rows
bad_data = pd.read_table('C:/Users/Ratnadeep/Desktop/python/Self Based Pandas/bad_data.txt',skiprows=[0,1,3])
bad_data
# Out:
#    1    deep  2000
# 0  2   ratna  3000
# 1  3    puja   120
# 2  4  adrija   120

# %%
#check null values
null_data = pd.read_table('C:/Users/Ratnadeep/Desktop/python/Self Based Pandas/null_data.txt')
null_data
pd.isnull(null_data)
# Out:
#       id   name    sal
# 0  False   True  False
# 1  False  False  False
# 2  False  False   True
# 3  False  False  False
# 4  False   True  False
# 5  False  False   True

# %%
pd.isnull(null_data).sum()
# Out:
# id      0
# name    2
# sal     2
# dtype: int64

# %%
#according to sheet
sht2 = pd.read_excel('C:/Users/Ratnadeep/Desktop/python/Self Based Pandas/Data.xlsx',sheet_name='Sheet2')
sht2
# Out:
#    x  y  z
# 0  1  7  9
# 1  3  6  8
# 2  6  6  8

# %%
#web Data
web_data = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
web_data
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(web_data)
# Out:
# list

# %%
#for getting the data in a table format
newdata =  web_data[0]
newdata.head(5)
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
#to check particular column data
newdata['Player'].head(5)
# Out:
# 0       Quincy Acy
# 1     Jordan Adams
# 2     Steven Adams
# 3      Jeff Adrien
# 4    Arron Afflalo
# Name: Player, dtype: object

# %%
newdata[['Player','Age']].head(5)
# Out:
#           Player Age
# 0     Quincy Acy  24
# 1   Jordan Adams  20
# 2   Steven Adams  21
# 3    Jeff Adrien  28
# 4  Arron Afflalo  29

# %%
type(newdata[['Player','Age']])
# Out:
# pandas.core.frame.DataFrame

# %%
#if we pull 1 row or 1 column then the data is called a serise
type(newdata['Player'])
# Out:
# pandas.core.series.Series

# %%
type(newdata[['Player']])
# Out:
# pandas.core.frame.DataFrame

# %%
#to check al the column name
newdata.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
#from github
git_data = pd.read_csv("https://github.com/abhionlyone/us-car-models-data/blob/master/2005.csv?raw=true")
git_data
# Out:
#      year   make model body_styles
# 0    2005  Acura   MDX     ["SUV"]
# 1    2005  Acura   NSX   ["Coupe"]
# 2    2005  Acura    RL   ["Sedan"]
# 3    2005  Acura   RSX   ["Coupe"]
# 4    2005  Acura    TL   ["Sedan"]
# ..    ...    ...   ...         ...
# 337  2005  Volvo   S80   ["Sedan"]
# 338  2005  Volvo   V50   ["Wagon"]
# 339  2005  Volvo   V70   ["Wagon"]
# 340  2005  Volvo  XC70   ["Wagon"]
# 341  2005  Volvo  XC90     ["SUV"]
#
# [342 rows x 4 columns]

# %%
df.head(2)
# Out:
#                                              Url Car  \
# 0  https://ikman.lk/en/ad/audi-a4-20tdi-2014-for-...
# 1  https://ikman.lk/en/ad/mercedes-benz-e300-nigh...
#
#                                     Name     Price          Brand Condition  \
# 0                    Audi A4 2.0TDi 2014   72500.0           Audi      Used
# 1  Mercedes Benz E300 Night Edition 2015  107500.0  Mercedes Benz      Used
#
#          Img                                            Img Url
# 0  Img/0.png  https://i.ikman-st.com/audi-a4-20tdi-2014-for-...
# 1  Img/0.png  https://i.ikman-st.com/mercedes-benz-e300-nigh...

# %%
#to know the column type
df.dtypes
# Out:
# Url Car       object
# Name          object
# Price        float64
# Brand         object
# Condition     object
# Img           object
# Img Url       object
# dtype: object

# %%
#change column name
df.rename(columns={'Name':'Car_name'})
# Out:
#                                                Url Car  \
# 0    https://ikman.lk/en/ad/audi-a4-20tdi-2014-for-...
# 1    https://ikman.lk/en/ad/mercedes-benz-e300-nigh...
# 2    https://ikman.lk/en/ad/mercedes-benz-c200-head...
# 3    https://ikman.lk/en/ad/toyota-axio-x-grade-200...
# 4    https://ikman.lk/en/ad/micro-panda-12000kms-20...
# ..                                                 ...
# 263  https://ikman.lk/en/ad/alfa-romeo-fiat-uno-lks...
# 264  https://ikman.lk/en/ad/toyota-land-cruiser-pra...
# 265  https://ikman.lk/en/ad/mercedes-benz-c180-cabr...
# 266  https://ikman.lk/en/ad/bmw-x1-s-drive-diesel-2...
# 267  https://ikman.lk/en/ad/toyota-prius-s-grade-20...
#
#                                    Car_name     Price          Brand  \
# 0                       Audi A4 2.0TDi 2014   72500.0           Audi
# 1     Mercedes Benz E300 Night Edition 2015  107500.0  Mercedes Benz
# 2    Mercedes Benz C200 headup display 2015  109000.0  Mercedes Benz
# ...
